# %%
import wumpus, hunter_AStar

# No pits, wumpus out of the way
# Minimum node count: 24
world_01 = {
  "id": "test world",
  "size": (10, 10),
  "hunters": [(0, 0, "N")],
  "pits": [],
  "wumpuses": [(0, 9)],
  "exits": [(0, 0)],
  "golds": [(5, 5)]
}

episode_result = wumpus.run_episode(wumpus.WumpusWorld.from_JSON(world_01), hunter_AStar.AStarPlayer(), show=True, horizon=100)
# Out:
# World details:
#   Size: (10, 10)
#   Pits: []
#   Wumpus: [(0, 9)]
#   Gold: [(5, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# ['MOVE', 'RIGHT', 'LEFT', 'SHOOT', 'GRAB', 'CLIMB']
# Insert the corresponding number and press ENTER to choose an heuristic:
# 	1: NONE
# 	2: MANHATTAN_SIMPLE
# 	3: MANHATTAN_PIVOTS
# 	4: MANHATTAN_OBSTACLE
# 	5: MANHATTAN_ITERATIVE_SHIFT
# 	6: FLOOD_FILL
# 	7: AREA_PRUNING
# ---------- RESULT ---------
# The algorithm has explored 123 node(s)
# Search was completed in 0.01024 seconds
# Found solution:
# ...

# %%
# Simple world with some pits and wumpus, no need to kill it
# Minimum node count: 30
world_02 = {
  "id": "test world",
  "size": (10, 10),
  "hunters": [(0, 0, "N")],
  "pits": [(2, 1), (3, 1), (4, 1), (5, 1), (5, 2), (0, 3), (1, 3), (2, 3), (3, 3), (6,4), (7,4)],
  "wumpuses": [(5, 4)],
  "exits": [(0, 0)],
  "golds": [(5, 5)]
}

episode_result = wumpus.run_episode(wumpus.WumpusWorld.from_JSON(world_02), hunter_AStar.AStarPlayer(), show=True, horizon=100)
# Out:
# World details:
#   Size: (10, 10)
#   Pits: [(2, 1), (3, 1), (4, 1), (5, 1), (5, 2), (0, 3), (1, 3), (2, 3), (3, 3), (6, 4), (7, 4)]
#   Wumpus: [(5, 4)]
#   Gold: [(5, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# ['MOVE', 'RIGHT', 'LEFT', 'SHOOT', 'GRAB', 'CLIMB']
# Insert the corresponding number and press ENTER to choose an heuristic:
# 	1: NONE
# 	2: MANHATTAN_SIMPLE
# 	3: MANHATTAN_PIVOTS
# 	4: MANHATTAN_OBSTACLE
# 	5: MANHATTAN_ITERATIVE_SHIFT
# 	6: FLOOD_FILL
# 	7: AREA_PRUNING
# ---------- RESULT ---------
# The algorithm has explored 187 node(s)
# Search was completed in 0.023798 seconds
# Found solution:
# ...

# %%
# World where the gold is guarded by the wumpus
# Minimum node count: 28
world_03 = {
  "id": "test world",
  "size": (10, 10),
  "hunters": [(0, 0, "N")],
  "pits": [(6, 4), (6, 5), (6, 6), (5, 6), (4, 6), (4, 5), (4, 4)],
  "wumpuses": [(5, 4)],
  "exits": [(0, 0)],
  "golds": [(5, 5)]
}

episode_result = wumpus.run_episode(wumpus.WumpusWorld.from_JSON(world_03), hunter_AStar.AStarPlayer(), show=True, horizon=100)
# Out:
# World details:
#   Size: (10, 10)
#   Pits: [(6, 4), (6, 5), (6, 6), (5, 6), (4, 6), (4, 5), (4, 4)]
#   Wumpus: [(5, 4)]
#   Gold: [(5, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# ['MOVE', 'RIGHT', 'LEFT', 'SHOOT', 'GRAB', 'CLIMB']
# Insert the corresponding number and press ENTER to choose an heuristic:
# 	1: NONE
# 	2: MANHATTAN_SIMPLE
# 	3: MANHATTAN_PIVOTS
# 	4: MANHATTAN_OBSTACLE
# 	5: MANHATTAN_ITERATIVE_SHIFT
# 	6: FLOOD_FILL
# 	7: AREA_PRUNING
# ---------- RESULT ---------
# The algorithm has explored 261 node(s)
# Search was completed in 0.022778 seconds
# Found solution:
# ...

# %%
# World where the gold and the wumpus are in the same position
# Minimum node count: 28
world_04 = {
  "id": "test world",
  "size": (10, 10),
  "hunters": [(0, 0, "N")],
  "pits": [],
  "wumpuses": [(5, 5)],
  "exits": [(0, 0)],
  "golds": [(5, 5)]
}

episode_result = wumpus.run_episode(wumpus.WumpusWorld.from_JSON(world_04), hunter_AStar.AStarPlayer(), show=True, horizon=100)
# Out:
# World details:
#   Size: (10, 10)
#   Pits: []
#   Wumpus: [(5, 5)]
#   Gold: [(5, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# ['MOVE', 'RIGHT', 'LEFT', 'SHOOT', 'GRAB', 'CLIMB']
# Insert the corresponding number and press ENTER to choose an heuristic:
# 	1: NONE
# 	2: MANHATTAN_SIMPLE
# 	3: MANHATTAN_PIVOTS
# 	4: MANHATTAN_OBSTACLE
# 	5: MANHATTAN_ITERATIVE_SHIFT
# 	6: FLOOD_FILL
# 	7: AREA_PRUNING
# ---------- RESULT ---------
# The algorithm has explored 122 node(s)
# Search was completed in 0.010009 seconds
# Found solution:
# ...

# %%
# World where killing the wumpus is optional, but beneficial
# Minimum node count: 20
world_05 = {
  "id": "test world",
  "size": (10, 10),
  "hunters": [(0, 0, "N")],
  "pits": [(0, 1), (0, 2), (2, 1), (2, 2), (3, 2), (4, 2)],
  "wumpuses": [(1, 2)],
  "exits": [(0, 0)],
  "golds": [(2, 3)]
}

episode_result = wumpus.run_episode(wumpus.WumpusWorld.from_JSON(world_05), hunter_AStar.AStarPlayer(), show=True, horizon=100)
# Out:
# World details:
#   Size: (10, 10)
#   Pits: [(0, 1), (0, 2), (2, 1), (2, 2), (3, 2), (4, 2)]
#   Wumpus: [(1, 2)]
#   Gold: [(2, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
# ['MOVE', 'RIGHT', 'LEFT', 'SHOOT', 'GRAB', 'CLIMB']
# Insert the corresponding number and press ENTER to choose an heuristic:
# 	1: NONE
# 	2: MANHATTAN_SIMPLE
# 	3: MANHATTAN_PIVOTS
# 	4: MANHATTAN_OBSTACLE
# 	5: MANHATTAN_ITERATIVE_SHIFT
# 	6: FLOOD_FILL
# 	7: AREA_PRUNING
# ---------- RESULT ---------
# The algorithm has explored 67 node(s)
# Search was completed in 0.007006 seconds
# Found solution:
# [<Actions.RIGHT: 1>, <Actions.MOVE: 0>, <Actions.LEFT: 2>, <Actions.MOVE: 0>, <Actions.SHOOT: 3>, <Actions.MOVE: 0>, <Actions.MOVE: 0>, <Actions.RIGHT: 1>, <Actions.MOVE: 0>, <Actions.GRAB: 4>, <Actions.LEFT: 2>, <Actions.LEFT: 2>, <Actions.MOVE: 0>, <Actions.LEFT: 2>, <Actions.MOVE: 0>, <Actions.MOVE: 0>, <Actions.MOVE: 0>, <Actions.RIGHT: 1>, <Actions.MOVE: 0>, <Actions.CLIMB: 5>]
# ---------------------------
# ...

# %%
# World where killing the wumpus is optional, but not beneficial
# Minimum node count: 22
world_06 = {
  "id": "test world",
  "size": (10, 10),
  "hunters": [(0, 0, "N")],
  "pits": [(0, 1), (0, 2), (2, 1), (2, 2), (3, 2), (4, 2)],
  "wumpuses": [(1, 2)],
  "exits": [(0, 0)],
  "golds": [(3, 3)]
}

episode_result = wumpus.run_episode(wumpus.WumpusWorld.from_JSON(world_06), hunter_AStar.AStarPlayer(), show=True, horizon=100)
# Out:
# World details:
#   Size: (10, 10)
#   Pits: [(0, 1), (0, 2), (2, 1), (2, 2), (3, 2), (4, 2)]
#   Wumpus: [(1, 2)]
#   Gold: [(3, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
# ['MOVE', 'RIGHT', 'LEFT', 'SHOOT', 'GRAB', 'CLIMB']
# Insert the corresponding number and press ENTER to choose an heuristic:
# 	1: NONE
# 	2: MANHATTAN_SIMPLE
# 	3: MANHATTAN_PIVOTS
# 	4: MANHATTAN_OBSTACLE
# 	5: MANHATTAN_ITERATIVE_SHIFT
# 	6: FLOOD_FILL
# 	7: AREA_PRUNING
# ---------- RESULT ---------
# The algorithm has explored 84 node(s)
# Search was completed in 0.009008 seconds
# Found solution:
# ...

# %%
# World where the gold is not reachable
# Minimum node count: 1
world_07 = {
  "id": "test world",
  "size": (10, 10),
  "hunters": [(0, 0, "N")],
  "pits": [(2, 0), (2, 1), (2, 2), (1, 2), (0, 2)],
  "wumpuses": [(9, 0)],
  "exits": [(0, 0)],
  "golds": [(5, 5)]
}

episode_result = wumpus.run_episode(wumpus.WumpusWorld.from_JSON(world_07), hunter_AStar.AStarPlayer(), show=True, horizon=100)
# Out:
# World details:
#   Size: (10, 10)
#   Pits: [(2, 0), (2, 1), (2, 2), (1, 2), (0, 2)]
#   Wumpus: [(9, 0)]
#   Gold: [(5, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# ['MOVE', 'RIGHT', 'LEFT', 'SHOOT', 'GRAB', 'CLIMB']
# Insert the corresponding number and press ENTER to choose an heuristic:
# 	1: NONE
# 	2: MANHATTAN_SIMPLE
# 	3: MANHATTAN_PIVOTS
# 	4: MANHATTAN_OBSTACLE
# 	5: MANHATTAN_ITERATIVE_SHIFT
# 	6: FLOOD_FILL
# 	7: AREA_PRUNING
# ---------- RESULT ---------
# The algorithm has explored 1 node(s)
# Search was completed in 0.0 seconds
# No viable solution was found! Climbing out
# ---------------------------
# ┌───┬───┬───┬───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │   │   │
# ...
