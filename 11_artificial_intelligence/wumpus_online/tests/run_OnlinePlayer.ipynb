# %%
import sys
sys.path.append("..")
import custom_player, wumpus

# %%
world = {
    "id": "wumpus-v0",
    "size": [6, 6],
    "hunters": [[0, 0, "N"]],
    "pits": [[0, 5], [5, 1], [3, 1], [3, 3], [2, 2], [4, 3], [3, 5]],
    "wumpuses": [[5, 4]],
    "golds": [[5, 3]]
}

ep_res = wumpus.run_episode(wumpus.WumpusWorld.from_JSON(world), custom_player.CustomPlayer(), show=True, horizon=100)
# Out:
# ┌───┬───┬───┬───┬───┬───┐
# │  P│   │   │  P│   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │W  │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│  P│ G │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │  P│   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│   │  P│
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │
# │ @^│   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┘
# Step 0: agent Hunter_43e6f0d0 executing MOVE -> reward -1
# ┌───┬───┬───┬───┬───┬───┐
# │  P│   │   │  P│   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │W  │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│  P│ G │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │  P│   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│   │  P│
# ...

# %%
# Random world
wumpus.run_episode(wumpus.WumpusWorld.random(size = 8), custom_player.CustomPlayer(truth_threshold = 0.85), show=True, horizon=1000)
# Out:
# Hello2
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │  P│  P│   │  P│   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │W  │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │  P│  P│   │  P│  P│   │  P│
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │  P│   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │  P│   │  P│   │   │   │   │  P│
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │ GP│   │   │   │  P│  P│  P│
# │ @^│   │   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┴───┘
# Step 0: agent Hunter_59d42ef8 executing CLIMB -> reward -1
# ...

# %%
world = {
  "id": "test world",
  "size": (5, 5),
  "hunters": [(0, 0, "N")],
  "pits": [(0,4), (4,3), (0,2), (4,1)],
  "wumpuses": [(2, 1)],
  "exits": [(0, 0)],
  "golds": [(4, 4)]
}

episode_result = wumpus.run_episode(wumpus.WumpusWorld.from_JSON(world), custom_player.CustomPlayer(), show=True, horizon=100)
# Out:
# ┌───┬───┬───┬───┬───┐
# │  P│   │   │   │ G │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │  P│
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │  P│   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │W  │   │  P│
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │ @^│   │   │   │   │
# └───┴───┴───┴───┴───┘
# Step 0: agent Hunter_97904ea5 executing MOVE -> reward -1
# ┌───┬───┬───┬───┬───┐
# │  P│   │   │   │ G │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │  P│
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │  P│   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │W  │   │  P│
# │ @^│   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │   │   │   │   │   │
# └───┴───┴───┴───┴───┘
# Step 1: agent Hunter_97904ea5 executing LEFT -> reward -1
# ┌───┬───┬───┬───┬───┐
# │  P│   │   │   │ G │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# ...
