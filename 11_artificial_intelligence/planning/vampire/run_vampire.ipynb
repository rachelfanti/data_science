# %%
# !fast-downward domain.pddl p01.pddl --heuristic "h=blind()" --search "eager_greedy([h])"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/local/Caskroom/miniconda/base/envs/aima2021/bin/python /usr/local/Caskroom/miniconda/base/envs/aima2021/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py domain.pddl p01.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.002s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.003s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 43 rules.
# Computing model... [0.010s CPU, 0.002s wall-clock]
# 45 relevant atoms
# 139 auxiliary atoms
# 184 final queue length
# 497 total queue pushes
# Completing instantiation... [0.000s CPU, 0.001s wall-clock]
# ...

# %%
# !fast-downward domain.pddl p02.pddl --heuristic "h=blind()" --search "eager_greedy([h])"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/local/Caskroom/miniconda/base/envs/aima2021/bin/python /usr/local/Caskroom/miniconda/base/envs/aima2021/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py domain.pddl p02.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.003s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.010s CPU, 0.003s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 43 rules.
# Computing model... [0.000s CPU, 0.002s wall-clock]
# 46 relevant atoms
# 139 auxiliary atoms
# 185 final queue length
# 499 total queue pushes
# Completing instantiation... [0.000s CPU, 0.001s wall-clock]
# ...

# %%
# !fast-downward domain.pddl p03.pddl --heuristic "h=blind()" --search "eager_greedy([h])"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/local/Caskroom/miniconda/base/envs/aima2021/bin/python /usr/local/Caskroom/miniconda/base/envs/aima2021/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py domain.pddl p03.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.003s wall-clock]
# Normalizing task... [0.010s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 43 rules.
# Computing model... [0.000s CPU, 0.002s wall-clock]
# 45 relevant atoms
# 139 auxiliary atoms
# 184 final queue length
# 495 total queue pushes
# Completing instantiation... [0.000s CPU, 0.001s wall-clock]
# ...

# %%
# !fast-downward domain.pddl p04.pddl --heuristic "h=blind()" --search "eager_greedy([h])"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/local/Caskroom/miniconda/base/envs/aima2021/bin/python /usr/local/Caskroom/miniconda/base/envs/aima2021/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py domain.pddl p04.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.004s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.010s CPU, 0.002s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 43 rules.
# Computing model... [0.000s CPU, 0.002s wall-clock]
# 45 relevant atoms
# 139 auxiliary atoms
# 184 final queue length
# 495 total queue pushes
# Completing instantiation... [0.000s CPU, 0.001s wall-clock]
# ...

# %%
# !fast-downward domain.pddl p05.pddl --heuristic "h=blind()" --search "eager_greedy([h])"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/local/Caskroom/miniconda/base/envs/aima2021/bin/python /usr/local/Caskroom/miniconda/base/envs/aima2021/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py domain.pddl p05.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.010s CPU, 0.003s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 43 rules.
# Computing model... [0.000s CPU, 0.002s wall-clock]
# 45 relevant atoms
# 139 auxiliary atoms
# 184 final queue length
# 495 total queue pushes
# Completing instantiation... [0.000s CPU, 0.002s wall-clock]
# ...

# %%
# !fast-downward domain.pddl p06.pddl --heuristic "h=blind()" --search "eager_greedy([h])"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/local/Caskroom/miniconda/base/envs/aima2021/bin/python /usr/local/Caskroom/miniconda/base/envs/aima2021/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py domain.pddl p06.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.010s CPU, 0.003s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 43 rules.
# Computing model... [0.000s CPU, 0.005s wall-clock]
# 86 relevant atoms
# 274 auxiliary atoms
# 360 final queue length
# 1681 total queue pushes
# Completing instantiation... [0.010s CPU, 0.003s wall-clock]
# ...

# %%
# !fast-downward domain.pddl p07.pddl --heuristic "h=blind()" --search "eager_greedy([h])"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/local/Caskroom/miniconda/base/envs/aima2021/bin/python /usr/local/Caskroom/miniconda/base/envs/aima2021/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py domain.pddl p07.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.010s CPU, 0.004s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 43 rules.
# Computing model... [0.000s CPU, 0.004s wall-clock]
# 86 relevant atoms
# 274 auxiliary atoms
# 360 final queue length
# 1686 total queue pushes
# Completing instantiation... [0.010s CPU, 0.003s wall-clock]
# ...

# %%
# !fast-downward domain.pddl p08.pddl --heuristic "h=blind()" --search "eager_greedy([h])"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/local/Caskroom/miniconda/base/envs/aima2021/bin/python /usr/local/Caskroom/miniconda/base/envs/aima2021/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py domain.pddl p08.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.003s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.010s CPU, 0.002s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 43 rules.
# Computing model... [0.000s CPU, 0.005s wall-clock]
# 85 relevant atoms
# 274 auxiliary atoms
# 359 final queue length
# 1682 total queue pushes
# Completing instantiation... [0.000s CPU, 0.002s wall-clock]
# ...

# %%
# !fast-downward domain.pddl p09.pddl --heuristic "h=blind()" --search "eager_greedy([h])"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/local/Caskroom/miniconda/base/envs/aima2021/bin/python /usr/local/Caskroom/miniconda/base/envs/aima2021/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py domain.pddl p09.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.003s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.010s CPU, 0.003s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 43 rules.
# Computing model... [0.000s CPU, 0.008s wall-clock]
# 125 relevant atoms
# 409 auxiliary atoms
# 534 final queue length
# 3567 total queue pushes
# Completing instantiation... [0.010s CPU, 0.004s wall-clock]
# ...

# %%
# !fast-downward domain.pddl p10.pddl --heuristic "h=blind()" --search "eager_greedy([h])"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/local/Caskroom/miniconda/base/envs/aima2021/bin/python /usr/local/Caskroom/miniconda/base/envs/aima2021/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py domain.pddl p10.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.010s CPU, 0.003s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 43 rules.
# Computing model... [0.010s CPU, 0.008s wall-clock]
# 124 relevant atoms
# 409 auxiliary atoms
# 533 final queue length
# 3579 total queue pushes
# Completing instantiation... [0.000s CPU, 0.004s wall-clock]
# ...
